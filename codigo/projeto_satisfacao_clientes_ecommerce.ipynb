# %%
#configurando o diretorio
import os
os.chdir("/Users/laura.nonato/Downloads/cursos/archive")

# %%
#carregando as bibliotecas
import pandas as pd

# %% [markdown]
# CARREGAMENTO DOS DADOS

# %%
#informações gerais sobre os pedidos
orders = pd.read_csv('olist_orders_dataset.csv')

# %%
#informações sobre avaliações dos pedidos
avaliacoes = pd.read_csv('olist_order_reviews_dataset.csv')

# %%
#informações sobre os clientes 
clientes = pd.read_csv('olist_customers_dataset.csv')

# %%
#informações sobre os itens dos pedidos  
itens_pedidos = pd.read_csv('olist_order_items_dataset.csv')

# %%
#informações sobre os produtos
produtos = pd.read_csv('olist_products_dataset.csv')

# %%
#informações sobre os vendedores
vendedores = pd.read_csv('olist_sellers_dataset.csv')

# %%
#informações sobre pagamentos dos pedidos  
pagamentos = pd.read_csv('olist_order_payments_dataset.csv')

# %%
#tradução dos produtos para o portugues
traducao = pd.read_csv('product_category_name_translation.csv')

# %% [markdown]
# ENTENDENDO OS DADOS CARREGADOS

# %%
orders.head(3)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00

# %%
#nome das colunas 
list(orders.columns.values)
# Out:
# ['order_id',
#  'customer_id',
#  'order_status',
#  'order_purchase_timestamp',
#  'order_approved_at',
#  'order_delivered_carrier_date',
#  'order_delivered_customer_date',
#  'order_estimated_delivery_date']

# %%
#tipos de dados
orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
#listando os possiveis valores missings na tabela orders
orders.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
avaliacoes.head(3)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             5                  NaN                    NaN
# 2             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp
# 0  2018-01-18 00:00:00     2018-01-18 21:46:59
# 1  2018-03-10 00:00:00     2018-03-11 03:05:13
# 2  2018-02-17 00:00:00     2018-02-18 14:36:24

# %%
pagamentos.head(3)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71

# %% [markdown]
# PREPARACAO DO DATASET DA ANALISE: MERGE

# %% [markdown]
# Merge de todos os datasets referentes ao **consumidor**

# %%
consumidor = pd.merge(orders, avaliacoes, on='order_id')
consumidor = pd.merge(consumidor, pagamentos,on='order_id')
consumidor = pd.merge(consumidor, clientes,on='customer_id')
consumidor.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date                         review_id  \
# 0           2017-10-18 00:00:00  a54f0611adc9ed256b57ede6b6eb5114
# 1           2017-10-18 00:00:00  a54f0611adc9ed256b57ede6b6eb5114
# 2           2017-10-18 00:00:00  a54f0611adc9ed256b57ede6b6eb5114
# 3           2018-08-13 00:00:00  8d5266042046a06655c8db133d120ba5
# 4           2018-09-04 00:00:00  e73b67b67587f7644d5bd1a52deb1b01
#
#    review_score  ... review_creation_date review_answer_timestamp  \
# 0             4  ...  2017-10-11 00:00:00     2017-10-12 03:43:48
# 1             4  ...  2017-10-11 00:00:00     2017-10-12 03:43:48
# 2             4  ...  2017-10-11 00:00:00     2017-10-12 03:43:48
# 3             4  ...  2018-08-08 00:00:00     2018-08-08 18:37:50
# 4             5  ...  2018-08-18 00:00:00     2018-08-22 19:07:58
#
#   payment_sequential payment_type  payment_installments payment_value  \
# 0                  1  credit_card                     1         18.12
# 1                  3      voucher                     1          2.00
# 2                  2      voucher                     1         18.59
# 3                  1       boleto                     1        141.46
# 4                  1  credit_card                     3        179.12
#
#                  customer_unique_id  customer_zip_code_prefix customer_city  \
# 0  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 1  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 2  7c396fd4830fd04220f754e42b4e5bff                      3149     sao paulo
# 3  af07308b275d755c9edb36a90c618231                     47813     barreiras
# 4  3a653a41f6f9fc3d2a113cf8398680e8                     75265    vianopolis
#
#    customer_state
# 0              SP
# 1              SP
# 2              SP
# 3              BA
# 4              GO
#
# [5 rows x 22 columns]

# %% [markdown]
# Merge de todos os datasets referentes ao **vendedor**

# %%
itens_pedidos.head(3)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
#
#    shipping_limit_date  price  freight_value
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-05-03 11:05:13  239.9          19.93
# 2  2018-01-18 14:48:30  199.0          17.87

# %%
produtos.head(3)
# Out:
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
# 2  96bd76ec8810374ed1b65e291975717f         esporte_lazer
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0

# %%
vendedores.head(3)
# Out:
#                           seller_id  seller_zip_code_prefix     seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023        campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844      mogi guacu
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031  rio de janeiro
#
#   seller_state
# 0           SP
# 1           SP
# 2           RJ

# %%
vendedor_produto  = pd.merge(itens_pedidos,produtos,on='product_id') #join de items pedidos e produtos por id do produto 
vendedor_produto  = pd.merge(vendedor_produto,vendedores,on='seller_id') #join dos produtos pedidos com a tabela de vendedores por seller_id
vendedor_produto  = pd.merge(vendedor_produto,traducao,on='product_category_name')
vendedor_produto .head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  130898c0987d1801452a8ed92a670612              1
# 2  532ed5e14e24ae1f0d735b91524b98b9              1
# 3  6f8c31653edb8c83e1a739408b5ff750              1
# 4  7d19f4ef4d04461989632411b7e588b9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
#
#    shipping_limit_date  price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.9          13.29            cool_stuff
# 1  2017-07-05 02:44:11   55.9          17.96            cool_stuff
# 2  2018-05-23 10:56:25   64.9          18.33            cool_stuff
# 3  2017-08-07 18:55:08   58.9          16.17            cool_stuff
# 4  2017-08-16 22:05:11   58.9          13.29            cool_stuff
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 58.0                       598.0                 4.0
# 1                 58.0                       598.0                 4.0
# 2                 58.0                       598.0                 4.0
# 3                 58.0                       598.0                 4.0
# 4                 58.0                       598.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             650.0               28.0                9.0              14.0
# 1             650.0               28.0                9.0              14.0
# 2             650.0               28.0                9.0              14.0
# 3             650.0               28.0                9.0              14.0
# 4             650.0               28.0                9.0              14.0
#
#    seller_zip_code_prefix    seller_city seller_state  \
# 0                   27277  volta redonda           SP
# 1                   27277  volta redonda           SP
# 2                   27277  volta redonda           SP
# 3                   27277  volta redonda           SP
# 4                   27277  volta redonda           SP
#
#   product_category_name_english
# 0                    cool_stuff
# 1                    cool_stuff
# 2                    cool_stuff
# 3                    cool_stuff
# 4                    cool_stuff

# %% [markdown]
# Merge dos datasets do **consumidor e do vendedor**

# %%
df_ecommerce = pd.merge(consumidor, vendedor_produto, on = 'order_id')
df_ecommerce.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2017-10-04 19:55:00           2017-10-10 21:25:13
# 2          2017-10-04 19:55:00           2017-10-10 21:25:13
# 3          2018-07-26 14:31:00           2018-08-07 15:27:45
# 4          2018-08-08 13:50:00           2018-08-17 18:06:29
#
#   order_estimated_delivery_date                         review_id  \
# 0           2017-10-18 00:00:00  a54f0611adc9ed256b57ede6b6eb5114
# 1           2017-10-18 00:00:00  a54f0611adc9ed256b57ede6b6eb5114
# 2           2017-10-18 00:00:00  a54f0611adc9ed256b57ede6b6eb5114
# 3           2018-08-13 00:00:00  8d5266042046a06655c8db133d120ba5
# 4           2018-09-04 00:00:00  e73b67b67587f7644d5bd1a52deb1b01
#
#    review_score  ... product_description_lenght product_photos_qty  \
# 0             4  ...                      268.0                4.0
# 1             4  ...                      268.0                4.0
# 2             4  ...                      268.0                4.0
# 3             4  ...                      178.0                1.0
# 4             5  ...                      232.0                1.0
#
#   product_weight_g product_length_cm  product_height_cm product_width_cm  \
# 0            500.0              19.0                8.0             13.0
# 1            500.0              19.0                8.0             13.0
# 2            500.0              19.0                8.0             13.0
# 3            400.0              19.0               13.0             19.0
# 4            420.0              24.0               19.0             21.0
#
#    seller_zip_code_prefix     seller_city seller_state  \
# 0                    9350            maua           SP
# 1                    9350            maua           SP
# 2                    9350            maua           SP
# 3                   31570  belo horizonte           SP
# 4                   14840         guariba           SP
#
#    product_category_name_english
# 0                     housewares
# 1                     housewares
# 2                     housewares
# 3                      perfumery
# 4                           auto
#
# [5 rows x 40 columns]

# %% [markdown]
# SELEÇÃO DOS DADOS DO DATASET
# restringindo o dataset para as colunas que realmente irei trabalhar a analise

# %%
df_ecommerce = (df_ecommerce.loc[:,['order_status','order_purchase_timestamp','order_delivered_customer_date','order_estimated_delivery_date','shipping_limit_date'
,'payment_sequential','payment_type','payment_installments','payment_value','price'
,'freight_value','product_category_name','product_name_lenght','product_description_lenght','product_photos_qty','review_score']])

# %%
df_ecommerce = df_ecommerce.rename(columns={'product_name_lenght': 'product_name_length', 'product_description_lenght': 'product_description_length',
                                            'product_category_name_english': 'product_category'})

# %%
df_ecommerce.head()
# Out:
#   order_status order_purchase_timestamp order_delivered_customer_date  \
# 0    delivered      2017-10-02 10:56:33           2017-10-10 21:25:13
# 1    delivered      2017-10-02 10:56:33           2017-10-10 21:25:13
# 2    delivered      2017-10-02 10:56:33           2017-10-10 21:25:13
# 3    delivered      2018-07-24 20:41:37           2018-08-07 15:27:45
# 4    delivered      2018-08-08 08:38:49           2018-08-17 18:06:29
#
#   order_estimated_delivery_date  shipping_limit_date  payment_sequential  \
# 0           2017-10-18 00:00:00  2017-10-06 11:07:15                   1
# 1           2017-10-18 00:00:00  2017-10-06 11:07:15                   3
# 2           2017-10-18 00:00:00  2017-10-06 11:07:15                   2
# 3           2018-08-13 00:00:00  2018-07-30 03:24:27                   1
# 4           2018-09-04 00:00:00  2018-08-13 08:55:23                   1
#
#   payment_type  payment_installments  payment_value   price  freight_value  \
# 0  credit_card                     1          18.12   29.99           8.72
# 1      voucher                     1           2.00   29.99           8.72
# 2      voucher                     1          18.59   29.99           8.72
# 3       boleto                     1         141.46  118.70          22.76
# 4  credit_card                     3         179.12  159.90          19.22
#
#    product_category_name  product_name_length  product_description_length  \
# 0  utilidades_domesticas                 40.0                       268.0
# 1  utilidades_domesticas                 40.0                       268.0
# 2  utilidades_domesticas                 40.0                       268.0
# 3             perfumaria                 29.0                       178.0
# 4             automotivo                 46.0                       232.0
#
#    product_photos_qty  review_score
# 0                 4.0             4
# 1                 4.0             4
# 2                 4.0             4
# 3                 1.0             4
# 4                 1.0             5

# %%
#tamanho do dataset final
df_ecommerce.shape
# Out:
# (115609, 16)

# %% [markdown]
# limpeza e pré processamento do dataset

# %%
#verifico os valores nulos em toda tabela 
df_ecommerce.isnull().sum()
# Out:
# order_status                        0
# order_purchase_timestamp            0
# order_delivered_customer_date    2400
# order_estimated_delivery_date       0
# shipping_limit_date                 0
# payment_sequential                  0
# payment_type                        0
# payment_installments                0
# payment_value                       0
# price                               0
# freight_value                       0
# product_category_name               0
# product_name_length                 0
# product_description_length          0
# product_photos_qty                  0
# review_score                        0
# dtype: int64

# %%
#removo os valores nulos
df_ecommerce.dropna(how='any',inplace=True)

# %%
#converto o timestamp para date, precisarei apenas do formato de data dos pedidos
cols = ['order_purchase_timestamp', 'order_estimated_delivery_date', 'order_delivered_customer_date', 'shipping_limit_date']
for col in cols:
    df_ecommerce[col] = pd.to_datetime(df_ecommerce[col]).dt.date

# %%
df_ecommerce['shipping_limit_date']
# Out:
# 0         2017-10-06
# 1         2017-10-06
# 2         2017-10-06
# 3         2018-07-30
# 4         2018-08-13
#              ...
# 115604    2018-02-12
# 115605    2017-09-05
# 115606    2018-01-12
# 115607    2018-01-12
# 115608    2018-03-15
# Name: shipping_limit_date, Length: 113209, dtype: object

# %%
#em relação a entrega dos pedidos, acrescentarei colunas que serao uteis para analise: 
# qt dias que demorou a entrega e qt de dias estimados para entrega
df_ecommerce['delivery_days'] = df_ecommerce['order_delivered_customer_date'] - df_ecommerce['order_purchase_timestamp']
df_ecommerce['estimated_days'] = df_ecommerce['order_estimated_delivery_date'] - df_ecommerce['order_purchase_timestamp']
df_ecommerce['shipping_days'] = df_ecommerce['shipping_limit_date'] - df_ecommerce['order_purchase_timestamp']

# %%
df_ecommerce['shipping_days']
# Out:
# 0        4 days
# 1        4 days
# 2        4 days
# 3        6 days
# 4        5 days
#           ...
# 115604   6 days
# 115605   9 days
# 115606   4 days
# 115607   4 days
# 115608   7 days
# Name: shipping_days, Length: 113209, dtype: timedelta64[ns]

# %%
#com o timedelta() converto os campos com qt de dias para o tipo inteiro, foi criado como string
df_ecommerce.astype({
    'delivery_days':'int64'
    ,'estimated_days':'int64'
    ,'shipping_days':'int64'
})
# Out:
#        order_status order_purchase_timestamp order_delivered_customer_date  \
# 0         delivered               2017-10-02                    2017-10-10
# 1         delivered               2017-10-02                    2017-10-10
# 2         delivered               2017-10-02                    2017-10-10
# 3         delivered               2018-07-24                    2018-08-07
# 4         delivered               2018-08-08                    2018-08-17
# ...             ...                      ...                           ...
# 115604    delivered               2018-02-06                    2018-02-28
# 115605    delivered               2017-08-27                    2017-09-21
# 115606    delivered               2018-01-08                    2018-01-25
# 115607    delivered               2018-01-08                    2018-01-25
# 115608    delivered               2018-03-08                    2018-03-16
#
#        order_estimated_delivery_date shipping_limit_date  payment_sequential  \
# 0                         2017-10-18          2017-10-06                   1
# 1                         2017-10-18          2017-10-06                   3
# 2                         2017-10-18          2017-10-06                   2
# 3                         2018-08-13          2018-07-30                   1
# 4                         2018-09-04          2018-08-13                   1
# ...                              ...                 ...                 ...
# 115604                    2018-03-02          2018-02-12                   1
# 115605                    2017-09-27          2017-09-05                   1
# 115606                    2018-02-15          2018-01-12                   1
# 115607                    2018-02-15          2018-01-12                   1
# 115608                    2018-04-03          2018-03-15                   1
#
#        payment_type  payment_installments  payment_value   price  \
# 0       credit_card                     1          18.12   29.99
# 1           voucher                     1           2.00   29.99
# 2           voucher                     1          18.59   29.99
# 3            boleto                     1         141.46  118.70
# 4       credit_card                     3         179.12  159.90
# ...             ...                   ...            ...     ...
# 115604  credit_card                     3         195.00  174.90
# 115605  credit_card                     5         271.01  205.99
# 115606  credit_card                     4         441.16  179.99
# 115607  credit_card                     4         441.16  179.99
# 115608   debit_card                     1          86.86   68.50
#
#         freight_value   product_category_name  product_name_length  \
# 0                8.72   utilidades_domesticas                 40.0
# 1                8.72   utilidades_domesticas                 40.0
# 2                8.72   utilidades_domesticas                 40.0
# 3               22.76              perfumaria                 29.0
# 4               19.22              automotivo                 46.0
# ...               ...                     ...                  ...
# 115604          20.10                   bebes                 52.0
# 115605          65.02      eletrodomesticos_2                 51.0
# 115606          40.59  informatica_acessorios                 59.0
# 115607          40.59  informatica_acessorios                 59.0
# 115608          18.36            beleza_saude                 45.0
#
#         product_description_length  product_photos_qty  review_score  \
# 0                            268.0                 4.0             4
# 1                            268.0                 4.0             4
# 2                            268.0                 4.0             4
# 3                            178.0                 1.0             4
# 4                            232.0                 1.0             5
# ...                            ...                 ...           ...
# 115604                       828.0                 4.0             4
# 115605                       500.0                 2.0             5
# 115606                      1893.0                 1.0             2
# 115607                      1893.0                 1.0             2
# 115608                       569.0                 1.0             5
#
#         delivery_days  estimated_days  shipping_days
# 0                   8              16              4
# 1                   8              16              4
# 2                   8              16              4
# 3                  14              20              6
# 4                   9              27              5
# ...               ...             ...            ...
# 115604             22              24              6
# 115605             25              31              9
# 115606             17              38              4
# 115607             17              38              4
# 115608              8              26              7
#
# [113209 rows x 19 columns]

# %%
#seleciono a coluna apenas para confirmar a conversao do tipo de dado
df_ecommerce['delivery_days']
# Out:
# 0          8
# 1          8
# 2          8
# 3         14
# 4          9
#           ..
# 115604    22
# 115605    25
# 115606    17
# 115607    17
# 115608     8
# Name: delivery_days, Length: 113209, dtype: int64

# %% [markdown]
# ENTENDIMENTO RAPIDO DA TABELA FINAL

# %%
df_ecommerce.head(3)
# Out:
#   order_status order_purchase_timestamp order_delivered_customer_date  \
# 0    delivered               2017-10-02                    2017-10-10
# 1    delivered               2017-10-02                    2017-10-10
# 2    delivered               2017-10-02                    2017-10-10
#
#   order_estimated_delivery_date shipping_limit_date  payment_sequential  \
# 0                    2017-10-18          2017-10-06                   1
# 1                    2017-10-18          2017-10-06                   3
# 2                    2017-10-18          2017-10-06                   2
#
#   payment_type  payment_installments  payment_value  price  freight_value  \
# 0  credit_card                     1          18.12  29.99           8.72
# 1      voucher                     1           2.00  29.99           8.72
# 2      voucher                     1          18.59  29.99           8.72
#
#    product_category_name  product_name_length  product_description_length  \
# 0  utilidades_domesticas                 40.0                       268.0
# 1  utilidades_domesticas                 40.0                       268.0
# 2  utilidades_domesticas                 40.0                       268.0
#
#    product_photos_qty  review_score  delivery_days  estimated_days  \
# 0                 4.0             4              8              16
# 1                 4.0             4              8              16
# 2                 4.0             4              8              16
#
#    shipping_days
# 0              4
# 1              4
# 2              4

# %%
#os status distintos dos pedidos
df_ecommerce.order_status.unique()
# Out:
# array(['delivered', 'canceled'], dtype=object)

# %%
#as categorias distintas dos produtos
df_ecommerce.product_category_name.unique()
# Out:
# array(['utilidades_domesticas', 'perfumaria', 'automotivo', 'pet_shop',
#        'papelaria', 'moveis_decoracao', 'moveis_escritorio',
#        'ferramentas_jardim', 'informatica_acessorios', 'cama_mesa_banho',
#        'brinquedos', 'telefonia', 'beleza_saude', 'eletronicos', 'bebes',
#        'cool_stuff', 'relogios_presentes', 'climatizacao',
#        'esporte_lazer', 'livros_interesse_geral',
#        'construcao_ferramentas_construcao', 'eletroportateis',
#        'alimentos', 'malas_acessorios', 'fashion_underwear_e_moda_praia',
#        'fashion_bolsas_e_acessorios', 'instrumentos_musicais',
#        'construcao_ferramentas_iluminacao', 'livros_tecnicos',
#        'construcao_ferramentas_jardim', 'eletrodomesticos',
#        'market_place', 'agro_industria_e_comercio', 'artigos_de_festas',
#        'casa_conforto', 'cds_dvds_musicais',
#        'industria_comercio_e_negocios', 'consoles_games', 'moveis_quarto',
#        'construcao_ferramentas_seguranca', 'telefonia_fixa', 'bebidas',
#        'moveis_cozinha_area_de_servico_jantar_e_jardim',
#        'fashion_calcados', 'casa_construcao', 'audio',
#        'eletrodomesticos_2', 'cine_foto', 'moveis_sala', 'artes',
#        'fashion_roupa_masculina', 'artigos_de_natal', 'alimentos_bebidas',
#        'tablets_impressao_imagem', 'fashion_esporte', 'la_cuisine',
#        'flores', 'pcs', 'casa_conforto_2', 'portateis_casa_forno_e_cafe',
#        'dvds_blu_ray', 'construcao_ferramentas_ferramentas',
#        'moveis_colchao_e_estofado', 'sinalizacao_e_seguranca',
#        'fashion_roupa_feminina', 'fraldas_higiene', 'livros_importados',
#        'musica', 'artes_e_artesanato', 'fashion_roupa_infanto_juvenil',
#        'seguros_e_servicos'], dtype=object)

# %%
#teste para filtrar da linha 2 a linha 4
df_ecommerce[2:4]
# Out:
#   order_status order_purchase_timestamp order_delivered_customer_date  \
# 2    delivered               2017-10-02                    2017-10-10
# 3    delivered               2018-07-24                    2018-08-07
#
#   order_estimated_delivery_date shipping_limit_date  payment_sequential  \
# 2                    2017-10-18          2017-10-06                   2
# 3                    2018-08-13          2018-07-30                   1
#
#   payment_type  payment_installments  payment_value   price  freight_value  \
# 2      voucher                     1          18.59   29.99           8.72
# 3       boleto                     1         141.46  118.70          22.76
#
#    product_category_name  product_name_length  product_description_length  \
# 2  utilidades_domesticas                 40.0                       268.0
# 3             perfumaria                 29.0                       178.0
#
#    product_photos_qty  review_score  delivery_days  estimated_days  \
# 2                 4.0             4              8              16
# 3                 1.0             4             14              20
#
#    shipping_days
# 2              4
# 3              6

# %%
#carregamento das bibliotecas para visualizacao dos dados
import matplotlib.pyplot as plt
# !pip install seaborn
# Out:
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\laura.nonato\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      -------------------------------------- 292.8/292.8 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.23 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: scipy>=1.0 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.22.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\laura.nonato\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.2

# %%
import seaborn as sns

# %%
#distribuição das avaliacoes dos pedidos
sns.histplot(x='review_score', data=df_ecommerce)
# Out:
# <AxesSubplot:xlabel='review_score', ylabel='Count'>

# %%
#histograma com a distribuição dos tipos de pagamento
sns.histplot( x='payment_type', data=df_ecommerce)
# Out:
# <AxesSubplot:xlabel='payment_type', ylabel='Count'>
